# %% [markdown]
# ## Import packages

# %%
! pip install nltk numpy pandas unidecode python-dotenv tqdm rouge-score chromadb pdfminer.six docarray pymupdf llm-blender
! pip install transformers torch scikit-learn
! pip install langchain langchain-core langchain-community langchain_experimental langchain-chroma langchain_mistralai
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: nltk in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: numpy in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: unidecode in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (1.3.8)
# Requirement already satisfied: python-dotenv in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: tqdm in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (4.66.5)
# Requirement already satisfied: rouge-score in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: chromadb in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.5.3)
# Requirement already satisfied: pdfminer.six in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (20240706)
# Requirement already satisfied: docarray in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.40.0)
# Requirement already satisfied: pymupdf in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (1.24.10)
# Requirement already satisfied: llm-blender in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.0.2)
# Requirement already satisfied: click in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: absl-py in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: six>=1.14.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: build>=1.0.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (1.2.2)
# Requirement already satisfied: requests>=2.28 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (2.9.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.114.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: posthog>=2.4.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (3.6.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (1.66.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pdfminer.six) (43.0.1)
# Requirement already satisfied: rich>=13.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from docarray) (13.8.1)
# Requirement already satisfied: types-requests>=2.28.11.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from docarray) (2.32.0.20240914)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from docarray) (0.9.0)
# Requirement already satisfied: PyMuPDFb==1.24.10 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pymupdf) (1.24.10)
# Requirement already satisfied: transformers in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (4.44.2)
# Requirement already satisfied: torch in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (2.4.1)
# Requirement already satisfied: accelerate in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (0.34.2)
# Requirement already satisfied: safetensors in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (0.4.5)
# Requirement already satisfied: dataclasses-json in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (0.6.7)
# Requirement already satisfied: sentencepiece in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (0.2.0)
# Requirement already satisfied: protobuf in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from llm-blender) (4.25.4)
# Requirement already satisfied: packaging>=19.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.4.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: cffi>=1.12 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.38.5)
# Requirement already satisfied: anyio in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.4.0)
# Requirement already satisfied: certifi in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: coloredlogs in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: sympy in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.2)
# Requirement already satisfied: deprecated>=1.2.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (73.0.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.23.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from rich>=13.1.0->docarray) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from rich>=13.1.0->docarray) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.24.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from typing-inspect>=0.8.0->docarray) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (13.0.1)
# Requirement already satisfied: psutil in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from accelerate->llm-blender) (6.0.0)
# Requirement already satisfied: filelock in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (3.16.0)
# Requirement already satisfied: networkx in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (3.2.1)
# Requirement already satisfied: jinja2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (3.1.4)
# Requirement already satisfied: fsspec in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch->llm-blender) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->llm-blender) (12.6.68)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from dataclasses-json->llm-blender) (3.22.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.20.2)
# Requirement already satisfied: pycparser in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: mdurl~=0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->docarray) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from jinja2->torch->llm-blender) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (4.44.2)
# Requirement already satisfied: torch in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (2.4.1)
# Requirement already satisfied: scikit-learn in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: filelock in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.68)
# Requirement already satisfied: scipy>=1.6.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: langchain in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.2.16)
# Requirement already satisfied: langchain-core in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.2.40)
# Requirement already satisfied: langchain-community in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.2.17)
# Requirement already satisfied: langchain_experimental in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.0.65)
# Requirement already satisfied: langchain-chroma in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: langchain_mistralai in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (0.1.13)
# Requirement already satisfied: PyYAML>=5.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (0.1.120)
# Requirement already satisfied: numpy<2,>=1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain-core) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain-chroma) (0.5.3)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain-chroma) (0.114.2)
# Requirement already satisfied: httpx<1,>=0.25.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain_mistralai) (0.27.2)
# Requirement already satisfied: httpx-sse<1,>=0.3.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain_mistralai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from langchain_mistralai) (0.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.1)
# Requirement already satisfied: build>=1.0.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.30.6)
# Requirement already satisfied: posthog>=2.4.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.6.5)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.66.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.10.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.38.5)
# Requirement already satisfied: anyio in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (4.4.0)
# Requirement already satisfied: certifi in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.0.5)
# Requirement already satisfied: idna in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (3.10)
# Requirement already satisfied: sniffio in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.2->langchain_mistralai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from tokenizers<1,>=0.15.1->langchain_mistralai) (0.24.7)
# Requirement already satisfied: pyproject_hooks in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.4.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.0.1)
# Requirement already satisfied: filelock in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2024.6.1)
# Requirement already satisfied: six>=1.9.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.9.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: coloredlogs in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: protobuf in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.25.4)
# Requirement already satisfied: sympy in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.13.2)
# Requirement already satisfied: deprecated>=1.2.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (73.0.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from anyio->httpx<1,>=0.25.2->langchain_mistralai) (1.2.2)
# Requirement already satisfied: click>=8.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (13.8.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (13.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from importlib-resources->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.20.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)

# %%
import llm_blender
import os
import json
import nltk
import string
import numpy as np
import pandas as pd
from unidecode import unidecode
from sklearn.metrics.pairwise import cosine_similarity
from pathlib import Path
from tqdm import tqdm
from dotenv import load_dotenv
from getpass import getpass
from rouge_score import rouge_scorer

from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.llms import Ollama
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# ## Setup environment variables
#
# You have to define the following environment variables in the `.env` file, terminal environment, or input field within this Jupyter notebook:
# 1. MISTRAL_API_KEY

# %% [markdown]
# ## Import packages

# %%
env_variables = [
  'MISTRAL_API_KEY',
  'OPENAI_API_KEY',
]

load_dotenv()

for key in env_variables:
  value = os.getenv(key)

  if value is None:
    value = getpass(key)

  os.environ[key] = value

# %% [markdown]
# ## Download NLTK dictionaries
#
# These dictionaries are needed for further text preprocessing.

# %%
dict_ids = [
  'punkt_tab',
  'punkt',
  'stopwords',
  'wordnet',
]

for dict_id in dict_ids:
  nltk.download(dict_id, quiet=True)

# %% [markdown]
# ## Setup metrics

# %% [markdown]
# ## Setup LLMs

# %% [markdown]
# ### Text preprocessing
#
# Define a function for text preprocessing, which is an important step before calculating any metrics. This preprocessing function will help in cleaning the text data, making it ready for further analysis. The preprocessing involves several steps:
# 1. Lowercasing
# 2. Stopwords removal
# 3. Lemmatization
# 4. Remove accents from characters

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()

def preprocess(corpus: str) -> str:
  corpus = corpus.lower()
  stopset = nltk.corpus.stopwords.words('english') + nltk.corpus.stopwords.words('russian') + list(string.punctuation)
  tokens = nltk.word_tokenize(corpus)
  tokens = [t for t in tokens if t not in stopset]
  tokens = [lemmatizer.lemmatize(t) for t in tokens]
  corpus = ' '.join(tokens)
  corpus = unidecode(corpus)
  return corpus

# %% [markdown]
# ### Embedding Initialization
#
# Here we are initializing the Llama 3 embeddings model. The `OllamaEmbeddings` class is a component of the Ollama library, a set of pre-trained language models. This model is capable of embedding corpora of any length into a 4096-dimensional vector.
#
# The use of `OllamaEmbeddings` requires the installation of a local Ollama server, which can be found at https://ollama.com.

# %%
embeddings = OllamaEmbeddings(model='llama3.1')

# %% [markdown]
# ### Average embeddings cosine similarity metric
#
# This function calculates the average cosine similarity between expected answers and LLM predicted answers using their respective embeddings. Cosine similarity is a measure of similarity between two non-zero vectors of an inner product space that measures the cosine of the angle between them:
#
# $$
# K(a, b) = \frac{\sum \limits_{i=1}^n a_i b_i}{\sqrt{\sum \limits_{i=1}^n a_i^2} \cdot \sqrt{\sum \limits_{i=1}^n b_i^2}}
# $$

# %%
def embeddings_cosine_sim_metric(expected_answers: list[str], predicted_answers: list[str]) -> float:
  results = []

  for expected_answer, predicted_answer in zip(expected_answers, predicted_answers):
    expected_answer = preprocess(expected_answer)
    predicted_answer = preprocess(predicted_answer)

    expected_embedding = np.array(embeddings.embed_query(expected_answer))
    predicted_embedding = np.array(embeddings.embed_query(predicted_answer))

    sim = cosine_similarity(
      expected_embedding.reshape(1, -1),
      predicted_embedding.reshape(1, -1),
    )[0][0]

    results.append(sim)

  return np.mean(results)

# %% [markdown]
# ### BLEU Metric
#
# This function calculates the average BLEU (Bilingual Evaluation Understudy) score between expected answers and predicted answers. The BLEU score is a measure that compares a candidate translation of text to one or more reference translations.
#
# A smoothing function is defined to calculate the BLEU score. Smoothing is useful when a perfect match is not found. It ensures that the BLEU scores aren't zero.

# %%
smoothie_f = nltk.translate.bleu_score.SmoothingFunction().method4

def bleu_metric(expected_answers, predicted_answers):
  scores = []

  for expected_answer, predicted_answer in zip(expected_answers, predicted_answers):
    expected_answer = preprocess(expected_answer)
    predicted_answer = preprocess(predicted_answer)

    predicted_tokens = nltk.word_tokenize(predicted_answer)
    expected_tokens = [nltk.word_tokenize(expected_answer)]

    score = nltk.translate.bleu_score.sentence_bleu(
      expected_tokens,
      predicted_tokens,
      smoothing_function=smoothie_f,
    )

    scores.append(score)

  return np.mean(scores)

# %% [markdown]
# ### ROGUE-1 (Recall-Oriented Understudy for Gisting Evaluation 1-gram Scoring)

# %%
rogue_1_scorer = rouge_scorer.RougeScorer(['rouge1'], use_stemmer=True)

def rogue_1_metric(expected_answers, predicted_answers):
  scores = []

  for expected_answer, predicted_answer in zip(expected_answers, predicted_answers):
    expected_answer = preprocess(expected_answer)
    predicted_answer = preprocess(predicted_answer)

    result = rogue_1_scorer.score(expected_answer, predicted_answer)

    scores.append(result['rouge1'])

  return np.mean(scores)

# %% [markdown]
# ### ROGUE-L (Recall-Oriented Understudy for Gisting Evaluation Longest Common Subsequence)

# %%
rogue_l_scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

def rogue_l_metric(expected_answers, predicted_answers):
  scores = []

  for expected_answer, predicted_answer in zip(expected_answers, predicted_answers):
    expected_answer = preprocess(expected_answer)
    predicted_answer = preprocess(predicted_answer)

    result = rogue_l_scorer.score(expected_answer, predicted_answer)

    scores.append(result['rougeL'])

  return np.mean(scores)

# %% [markdown]
# ## Setup LLMs

# %% [markdown]
# ### Llama 3.1

# %%
def get_llama3_1_llm(temperature=0):
  return Ollama(model='llama3.1', temperature=temperature)

# %% [markdown]
# ### Mistral Large

# %%
def get_mistral_large_llm(temperature=0):
  return ChatMistralAI(
    model='mistral-large-latest',
    temperature=temperature,
  )

# %% [markdown]
# ### GPT-4o mini

# %%
def get_chatgpt_40_mini_llm(temperature=0):
  return ChatOpenAI(
    model='gpt-4o-mini',
    temperature=temperature,
  )

# %% [markdown]
# ## Setup experiments

# %% [markdown]
# ### Load QA dataset

# %%
qa_df = pd.read_csv('brainscape.csv')[:214]
qa_df
# Out:
#                                               question  \
# 0          What are the afferent cranial nerve nuclei?
# 1            What is the order of the cranial nerves ?
# 2          What are the efferent cranial nerve nuclei?
# 3    Which nuclei share the embryo logical origin -...
# 4    Which nuclei share the embryo logical origin- ...
# ..                                                 ...
# 209    What are spontaneous active bursting neurones ?
# 210                What is the patch-clamp technique ?
# 211  What toxin can be used to block sodium currents ?
# 212          What toxin can block potassium currents ?
# 213  What is the benefit of blocking the sodium and...
#
#                                                 answer
# 0    Trigeminal sensory nucleus- fibres carry gener...
# 1    1-olfactory\n2-optic\n3-oculomotor\n4-trochlea...
# 2    Edinger-westphal nucleus\nOculomotor nucleus\n...
# 3    Oculomotor nucleus Trochlear nucleus Abducens ...
# 4    Trigeminal motor nucleus Facial motor nucleus ...
# ..                                                 ...
# 209  These are pacemaker neurons They don’t require...
# 210  Enables recordings of electrical activity of a...
# 211             Tetrodotoxin-it blocks sodium channels
# 212           Tetrammonium - blocks potassium channels
# 213  It enables the ability to see the effects of c...
#
# [214 rows x 2 columns]

# %% [markdown]
# ### Setup experiment grid search parameters

# %%
llms = (
  # ('GPT-4o mini', get_chatgpt_40_mini_llm()),
  ('Mistral Large', get_mistral_large_llm()),
  ('LLaMA 3.1', get_llama3_1_llm()),
)

# %% [markdown]
# ### Conduct the experiment

# %%
blender = llm_blender.Blender()
blender.loadranker("llm-blender/PairRM")
blender.loadfuser("llm-blender/gen_fuser_3b")
# Out:
# WARNING:root:No ranker config provided, no ranker loaded, please load ranker first through load_ranker()
# WARNING:root:No fuser config provided, no fuser loaded, please load fuser first through load_fuser()
# /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages/dataclasses_json/core.py:201: RuntimeWarning: 'NoneType' object value of non-optional type load_checkpoint detected when decoding RankerConfig.
#   warnings.warn(
# /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages/dataclasses_json/core.py:201: RuntimeWarning: 'NoneType' object value of non-optional type device detected when decoding RankerConfig.
#   warnings.warn(
# /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /home/super-pc-linux/miniconda3/envs/biorag/lib/python3.9/site-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Successfully loaded ranker from  /home/super-pc-linux/.cache/huggingface/hub/llm-blender/PairRM

# %%
df = pd.DataFrame()

questions = qa_df['question'].tolist()
expected_answers = qa_df['answer'].tolist()

predicted_answers = []

for question in tqdm(questions, desc='Questions'):
  llm_answers = []

  for llm_name, llm in llms:
    chain = llm | StrOutputParser()
    llm_answer = chain.invoke(question)
    llm_answers.append(llm_answer)

  fuse_generations, ranks = blender.rank_and_fuse([question], [llm_answers], instructions=[''], return_scores=False, batch_size=2, top_k=3)
  predicted_answers.append(fuse_generations[0])

# Evaluate metrics
cos_sim = embeddings_cosine_sim_metric(expected_answers, predicted_answers)
bleu_score = bleu_metric(expected_answers, predicted_answers)
rogue_1_score = rogue_1_metric(expected_answers, predicted_answers)
rogue_l_score = rogue_l_metric(expected_answers, predicted_answers)

cos_sim, bleu_score, rogue_1_score, rogue_l_score
# Out:
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.90it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.89it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (534 > 512). Running this sequence through the model will result in indexing errors
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.79it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 29.46it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.24it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 28.04it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.91it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.93it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.84it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.63it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.57it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.78it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.03it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.10it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.26it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.60it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.73it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.88it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.10it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.19it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 28.51it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.07it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 30.17it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 26.88it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.51it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.57it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.78it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.87it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 31.12it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 33.56it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.16it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 28.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.72it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.89it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.10it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.35it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.46it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.03it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.72it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 12.85it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.92it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.72it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.03it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.27it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.37it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 10.51it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.59it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.90it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.78it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 12.48it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.20it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.98it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.18it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.93it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.82it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.87it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.95it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.40it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.67it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.28it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.88it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.26it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.53it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.75it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.26it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.73it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.22it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.71it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.02it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.93it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.78it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  8.55it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.37it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.28it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.87it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.54it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.07it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 29.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.88it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.87it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.97it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.96it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.24it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.38it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.15it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.81it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.79it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.08it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 12.12it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.07it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  9.28it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.60it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.49it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.10it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.82it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.30it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.62it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.29it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.21it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.10it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.75it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.71it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.72it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.23it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.25it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.10it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.67it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.94it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  8.15it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  9.97it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 12.99it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.80it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.40it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  7.72it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.04it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.90it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.16it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.00it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.46it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.38it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.42it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.25it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 31.68it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.89it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.03it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 26.98it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.40it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.40it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 29.45it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 28.86it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.31it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.42it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.00it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.57it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.05it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.93it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.69it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.61it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 25.79it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.84it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.82it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.74it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.85it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.95it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 29.40it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.84it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.64it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.15it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.09it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 26.52it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.28it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.67it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.01it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.14it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.81it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.64it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 21.94it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 10.82it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.64it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.13it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.38it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.41it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  8.48it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 12.88it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.18it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.45it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.14it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.22it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.51it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.04it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.28it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.29it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 28.59it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 29.12it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.46it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 13.98it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.72it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 19.23it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 23.97it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.63it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.78it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.66it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.24it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 10.59it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00,  9.61it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 24.67it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.60it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.95it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.42it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 14.53it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 16.02it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.06it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.22it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.25it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 17.17it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.63it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.09it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.77it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 20.38it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.50it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 18.20it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 15.96it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 28.74it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 22.94it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
# Ranking candidates: 100%|██████████| 1/1 [00:00<00:00, 27.20it/s]
# Fusing candidates: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Questions: 100%|██████████| 214/214 [52:52<00:00, 14.82s/it]
# (0.6120309928894316,
#  0.023211538364972827,
#  0.20501471533742882,
#  0.17992878112524957)
