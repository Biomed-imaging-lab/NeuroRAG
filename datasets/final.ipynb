# %%
import pandas as pd

# %%
medmcqa_df = pd.read_csv('medmcqa.csv')
mediqa_df = pd.read_csv('mediqa.csv')
brainscape_df = pd.read_csv('brainscape.csv')
mmlu_df = pd.read_csv('mmlu.csv')

final_df = pd.concat([
  medmcqa_df,
  mediqa_df,
  brainscape_df,
  mmlu_df,
])
final_df
# Out:
#                                                question  \
# 0     Following endaerectomy on the right common car...
# 1                                        Hypomimia is ?
# 2     With which of the following receptors theophyl...
# 3     During Sx for meningioma, the left paracentral...
# 4     All of the following structure lies outside th...
# ...                                                 ...
# 2541  Which of the following conditions best charact...
# 2542  Which of the following endocrine glands is NOT...
# 2543  Which of the following drugs is classified as ...
# 2544  School psychologists serve a variety of client...
# 2545  Why are psychoanalysts sometimes interested in...
#
#                                                  answer
# 0                            Central aery of the retina
# 1                      Deficit of expression by gesture
# 2                                   Adenosine receptors
# 3                                  Rt. Leg and perineus
# 4                                       Maxillary nerve
# ...                                                 ...
# 2541                                  Observable events
# 2542           hypothalamus–thyroid-stimulating hormone
# 2543                                           nicotine
# 2544                                            student
# 2545  Some psychoanalysts believe that dream symbols...
#
# [4622 rows x 2 columns]

# %%
final_df.to_csv('final.csv', index=False)
